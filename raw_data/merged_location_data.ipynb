# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# battle_deaths_by_country.csv
# battle_deaths_by_country_data_source.csv
# country_info.csv
# locations.csv
# merged_location_data.ipynb
# refugees_by_country_of_asylum.csv
# refugees_by_country_of_asylum_data_source.csv
# refugees_by_country_of_origin.csv
# refugees_by_country_of_origin_data_source.csv

# %%
locations =  pd.read_csv("locations.csv")
locations.drop(['Alpha-2 code', 'Alpha-3 code', 'Numeric code', 'Icon'], axis =1, inplace = True)
locations.rename(columns={'Country': 'Country Name'}, inplace=True)
locations.head()
# Out:
#      Country Name  Latitude (average)  Longitude (average)
# 0         Albania             41.0000                 20.0
# 1         Algeria             28.0000                  3.0
# 2  American Samoa            -14.3333               -170.0
# 3         Andorra             42.5000                  1.6
# 4          Angola            -12.5000                 18.5

# %%
battle_deaths_by_country = pd.read_csv("battle_deaths_by_country.csv")
battle_deaths_by_country
# Out:
#                                           Series Name  Series Code  \
# 0            Battle-related deaths (number of people)  VC.BTL.DETH
# 1            Battle-related deaths (number of people)  VC.BTL.DETH
# 2            Battle-related deaths (number of people)  VC.BTL.DETH
# 3            Battle-related deaths (number of people)  VC.BTL.DETH
# 4            Battle-related deaths (number of people)  VC.BTL.DETH
# 5            Battle-related deaths (number of people)  VC.BTL.DETH
# 6            Battle-related deaths (number of people)  VC.BTL.DETH
# 7            Battle-related deaths (number of people)  VC.BTL.DETH
# 8            Battle-related deaths (number of people)  VC.BTL.DETH
# 9            Battle-related deaths (number of people)  VC.BTL.DETH
# 10           Battle-related deaths (number of people)  VC.BTL.DETH
# 11           Battle-related deaths (number of people)  VC.BTL.DETH
# 12           Battle-related deaths (number of people)  VC.BTL.DETH
# ...

# %%
battle_deaths_by_country = pd.read_csv("battle_deaths_by_country.csv")
battle_deaths_by_country_merged = pd.merge(locations, battle_deaths_by_country, on='Country Name')
battle_deaths_by_country_merged
# Out:
#                  Country Name  Latitude (average)  Longitude (average)  \
# 0                     Albania             41.0000              20.0000
# 1                     Algeria             28.0000               3.0000
# 2              American Samoa            -14.3333            -170.0000
# 3                     Andorra             42.5000               1.6000
# 4                      Angola            -12.5000              18.5000
# 5         Antigua and Barbuda             17.0500             -61.8000
# 6                   Argentina            -34.0000             -64.0000
# 7                     Armenia             40.0000              45.0000
# 8                       Aruba             12.5000             -69.9667
# 9                   Australia            -27.0000             133.0000
# 10                    Austria             47.3333              13.3333
# 11                 Azerbaijan             40.5000              47.5000
# ...

# %%
battle_deaths_by_country_merged.to_csv("battle_deaths_by_country_merged.csv", encoding='utf-8', index=False)

# %%
data1 =  pd.read_csv("battle_deaths_by_country_merged.csv")
data1
# Out:
#                  Country Name  Latitude (average)  Longitude (average)  \
# 0                     Albania             41.0000              20.0000
# 1                     Algeria             28.0000               3.0000
# 2              American Samoa            -14.3333            -170.0000
# 3                     Andorra             42.5000               1.6000
# 4                      Angola            -12.5000              18.5000
# 5         Antigua and Barbuda             17.0500             -61.8000
# 6                   Argentina            -34.0000             -64.0000
# 7                     Armenia             40.0000              45.0000
# 8                       Aruba             12.5000             -69.9667
# 9                   Australia            -27.0000             133.0000
# 10                    Austria             47.3333              13.3333
# 11                 Azerbaijan             40.5000              47.5000
# ...

# %%
# !ls
# Out:
# battle_deaths_by_country.csv
# battle_deaths_by_country_data_source.csv
# battle_deaths_by_country_merged.csv
# country_info.csv
# locations.csv
# merged_location_data.ipynb
# refugees_by_country_of_asylum.csv
# refugees_by_country_of_asylum_data_source.csv
# refugees_by_country_of_origin.csv
# refugees_by_country_of_origin_data_source.csv

# %%
refugees_by_country_of_asylum = pd.read_csv("refugees_by_country_of_asylum.csv")
refugees_by_country_of_asylum
# Out:
#                                            Series Name  Series Code  \
# 0    Refugee population by country or territory of ...  SM.POP.REFG
# 1    Refugee population by country or territory of ...  SM.POP.REFG
# 2    Refugee population by country or territory of ...  SM.POP.REFG
# 3    Refugee population by country or territory of ...  SM.POP.REFG
# 4    Refugee population by country or territory of ...  SM.POP.REFG
# 5    Refugee population by country or territory of ...  SM.POP.REFG
# 6    Refugee population by country or territory of ...  SM.POP.REFG
# 7    Refugee population by country or territory of ...  SM.POP.REFG
# 8    Refugee population by country or territory of ...  SM.POP.REFG
# 9    Refugee population by country or territory of ...  SM.POP.REFG
# 10   Refugee population by country or territory of ...  SM.POP.REFG
# 11   Refugee population by country or territory of ...  SM.POP.REFG
# 12   Refugee population by country or territory of ...  SM.POP.REFG
# ...

# %%
refugees_by_country_of_asylum = pd.read_csv("refugees_by_country_of_asylum.csv")
refugees_by_country_of_asylum_merged = pd.merge(locations, refugees_by_country_of_asylum, on='Country Name')
refugees_by_country_of_asylum_merged.head()
# Out:
#      Country Name  Latitude (average)  Longitude (average)  \
# 0         Albania             41.0000                 20.0
# 1         Algeria             28.0000                  3.0
# 2  American Samoa            -14.3333               -170.0
# 3         Andorra             42.5000                  1.6
# 4          Angola            -12.5000                 18.5
#
#                                          Series Name  Series Code  \
# 0  Refugee population by country or territory of ...  SM.POP.REFG
# 1  Refugee population by country or territory of ...  SM.POP.REFG
# 2  Refugee population by country or territory of ...  SM.POP.REFG
# 3  Refugee population by country or territory of ...  SM.POP.REFG
# 4  Refugee population by country or territory of ...  SM.POP.REFG
#
#   Country Code 1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993]  \
# 0          ALB            ..            ..          3000          3000
# ...

# %%
refugees_by_country_of_asylum_merged.to_csv("refugees_by_country_of_asylum_merged.csv", encoding='utf-8', index=False)

# %%
data2 =  pd.read_csv("refugees_by_country_of_asylum_merged.csv")
data2
# Out:
#                  Country Name  Latitude (average)  Longitude (average)  \
# 0                     Albania             41.0000              20.0000
# 1                     Algeria             28.0000               3.0000
# 2              American Samoa            -14.3333            -170.0000
# 3                     Andorra             42.5000               1.6000
# 4                      Angola            -12.5000              18.5000
# 5         Antigua and Barbuda             17.0500             -61.8000
# 6                   Argentina            -34.0000             -64.0000
# 7                     Armenia             40.0000              45.0000
# 8                       Aruba             12.5000             -69.9667
# 9                   Australia            -27.0000             133.0000
# 10                    Austria             47.3333              13.3333
# 11                 Azerbaijan             40.5000              47.5000
# ...

# %%
# !ls
# Out:
# battle_deaths_by_country.csv
# battle_deaths_by_country_data_source.csv
# battle_deaths_by_country_merged.csv
# country_info.csv
# locations.csv
# merged_location_data.ipynb
# refugees_by_country_of_asylum.csv
# refugees_by_country_of_asylum_data_source.csv
# refugees_by_country_of_asylum_merged.csv
# refugees_by_country_of_origin.csv
# refugees_by_country_of_origin_data_source.csv

# %%
refugees_by_country_of_origin = pd.read_csv("refugees_by_country_of_origin.csv")
refugees_by_country_of_origin_merged = pd.merge(locations, refugees_by_country_of_origin, on='Country Name')
refugees_by_country_of_origin_merged.head()
# Out:
#      Country Name  Latitude (average)  Longitude (average)  \
# 0         Albania             41.0000                 20.0
# 1         Algeria             28.0000                  3.0
# 2  American Samoa            -14.3333               -170.0
# 3         Andorra             42.5000                  1.6
# 4          Angola            -12.5000                 18.5
#
#                                          Series Name     Series Code  \
# 0  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 1  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 2  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 3  Refugee population by country or territory of ...  SM.POP.REFG.OR
# 4  Refugee population by country or territory of ...  SM.POP.REFG.OR
#
#   Country Code 1990 [YR1990] 1991 [YR1991] 1992 [YR1992] 1993 [YR1993]  \
# 0          ALB          1822          3540          4353          4744
# ...

# %%
refugees_by_country_of_origin_merged.to_csv("refugees_by_country_of_origin_merged.csv", encoding='utf-8', index=False)

# %%
data3 =  pd.read_csv("refugees_by_country_of_origin_merged.csv")
data3
# Out:
#                  Country Name  Latitude (average)  Longitude (average)  \
# 0                     Albania             41.0000              20.0000
# 1                     Algeria             28.0000               3.0000
# 2              American Samoa            -14.3333            -170.0000
# 3                     Andorra             42.5000               1.6000
# 4                      Angola            -12.5000              18.5000
# 5         Antigua and Barbuda             17.0500             -61.8000
# 6                   Argentina            -34.0000             -64.0000
# 7                     Armenia             40.0000              45.0000
# 8                       Aruba             12.5000             -69.9667
# 9                   Australia            -27.0000             133.0000
# 10                    Austria             47.3333              13.3333
# 11                 Azerbaijan             40.5000              47.5000
# ...
